# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
df = pd.read_csv('compustat_dailly_ratings_1997_02_to_latest.csv')
# Out:
# C:\Users\Joseph\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2,3,6,7,8,14,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#splticrm: S&P Domestic Long Term Issuer Credit Rating
#datadate: date bond rating data was collected
#cik: company unique ID
#llc location
#Final data ~3k, most don't have long term ratings, filtered for US companies
df.columns
# Out:
# Index(['gvkey', 'splticrm', 'spsdrm', 'spsticrm', 'datadate', 'add1', 'add2',
#        'add3', 'add4', 'addzip', 'busdesc', 'cik', 'city', 'conml', 'county',
#        'dlrsn', 'ein', 'fax', 'fic', 'fyrc', 'ggroup', 'gind', 'gsector',
#        'gsubind', 'idbflag', 'incorp', 'loc', 'naics', 'phone', 'prican',
#        'prirow', 'priusa', 'sic', 'spcindcd', 'spcseccd', 'spcsrc', 'state',
#        'stko', 'weburl', 'dldte', 'ipodate', 'conm', 'tic', 'cusip'],
#       dtype='object')

# %%
df['splticrm'].value_counts()
# Out:
# BBB     60149
# B+      48345
# BBB+    47786
# BBB-    46539
# BB-     44129
# A-      37203
# A       35631
# B       34892
# BB      34450
# BB+     27469
# A+      22673
# B-      17720
# AA-     13008
# AA       7409
# CCC+     6865
# D        5208
# AAA      4420
# CCC      3515
# AA+      2430
# CC       1293
# CCC-     1126
# SD        666
# N.M.      182
# Name: splticrm, dtype: int64

# %%
df['spsdrm'].value_counts()
# Out:
# B-      2383
# B       2170
# B+      1438
# A-      1151
# BBB-    1106
# BB+      932
# BB-      864
# BBB      817
# BBB+     696
# A        518
# A+       453
# CCC+     423
# D        206
# AA-      192
# CCC      177
# AA        76
# CCC-      65
# AAA       30
# CC        22
# AA+       20
# C         12
# BB         5
# Name: spsdrm, dtype: int64

# %%
df['spsticrm'].value_counts()
# Out:
# A-2     68957
# A-1     44184
# A-1+    23304
# A-3     10871
# B        4062
# B-2      1128
# B-1       744
# C         593
# B-3       435
# D         368
# SD         10
# Name: spsticrm, dtype: int64

# %%
df['spcsrc'].value_counts()
# Out:
# C      395384
# B-     251865
# B      194856
# B+     155963
# D      107625
# A-      57821
# A       42623
# A+      12578
# LIQ      1248
# Name: spcsrc, dtype: int64

# %%
lista= ['splticrm','spsdrm','spsticrm','spcsrc']

# %%
for i in lista:
    print(i,':',df[i].isnull().sum())
# Out:
# splticrm : 1884358
# spsdrm : 2373710
# spsticrm : 2232810
# spcsrc : 1167503

# %%
mask = df['splticrm'].isna() | df['spsticrm'].isna()

# %%
df[-mask][['gvkey','splticrm','spsticrm','cik']]
# Out:
#           gvkey splticrm spsticrm        cik
# 1679       1045       B-      B-3     6201.0
# 1680       1045       B-      B-3     6201.0
# 1681       1045       B-      B-3     6201.0
# 1682       1045       B-      B-3     6201.0
# 1683       1045       B-      B-3     6201.0
# ...         ...      ...      ...        ...
# 2387171  295786      BB+        B  1567094.0
# 2387172  295786      BB+        B  1567094.0
# 2387173  295786      BB+        B  1567094.0
# 2387174  295786      BB+        B  1567094.0
# 2387175  295786      BB+        B  1567094.0
#
# [151191 rows x 4 columns]

# %% [markdown]
# # Return

# %%
returns = pd.read_csv('compustat_daily_prices_1997_02_to_latest.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-573f9cd64f67> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.ticker as mtick
# ----> 5 returns = pd.read_csv('compustat_daily_prices_1997_02_to_latest.csv')
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'compustat_daily_prices_1997_02_to_latest.csv' does not exist: b'compustat_daily_prices_1997_02_to_latest.csv'

# %%
returns.head()
# Out:
#    gvkey iid  datadate   tic      cusip                   conm  ajexm  ajpm  \
# 0   1003  01  19970131  ANTQ  000354100  A.A. IMPORTING CO INC    1.0   1.0
# 1   1003  01  19970228  ANTQ  000354100  A.A. IMPORTING CO INC    1.0   1.0
# 2   1003  01  19970331  ANTQ  000354100  A.A. IMPORTING CO INC    1.0   1.0
# 3   1003  01  19970430  ANTQ  000354100  A.A. IMPORTING CO INC    1.0   1.0
# 4   1003  01  19970531  ANTQ  000354100  A.A. IMPORTING CO INC    1.0   1.0
#
#   isalrt primiss  ...  priusa     sic  spcindcd  spcseccd spcsrc  state  stko  \
# 0    NaN       P  ...     1.0  5712.0     449.0     976.0    NaN     MO   3.0
# 1    NaN       P  ...     1.0  5712.0     449.0     976.0    NaN     MO   3.0
# 2    NaN       P  ...     1.0  5712.0     449.0     976.0    NaN     MO   3.0
# 3    NaN       P  ...     1.0  5712.0     449.0     976.0    NaN     MO   3.0
# 4    NaN       P  ...     1.0  5712.0     449.0     976.0    NaN     MO   3.0
#
#                 weburl       dldte  ipodate
# 0  www.aaimporting.com  19920430.0      NaN
# 1  www.aaimporting.com  19920430.0      NaN
# 2  www.aaimporting.com  19920430.0      NaN
# 3  www.aaimporting.com  19920430.0      NaN
# 4  www.aaimporting.com  19920430.0      NaN
#
# [5 rows x 83 columns]

# %%
returns['datadate']=(pd.to_datetime(returns['datadate'],format='%Y%m%d'))

# %%
returns['month']= returns['datadate'].dt.month
returns['year']= returns['datadate'].dt.year

# %%
returns['mkcap']= returns['cshom']* returns['prccm']

# %%
# Shift the stock by 1 month
mask = returns['cik']==returns['cik'].shift(-1)
returns['nextmonth_return']= np.where(mask,returns['trt1m'].shift(-1),np.nan)

# %%
# returns

# %%
returns= returns[['cik','prccm','year','month','datadate','trt1m','cshom','mkcap','tic','nextmonth_return']]

# CIK unique company identifier
# PRCCM close price
# CMTH month, CYEAR year
# datadate
# TRT1M monthly total return: monthly multiplication factor for calculating the total return to shareholders of any time period.
# includes Cash Equivalent Distributions (from 01-31-1982 and forward) along with reinvestment of dividends and the compounding effect of dividends paid on reinvested dividends.
# 'cshom' s/o monthly, 'chsoq' s/o quarterly

# %%
returns[returns['tic']=='AAPL']
# Out:
#             cik    prccm  year  month   datadate    trt1m         cshom  \
# 36629  320193.0   16.625  1997      1 1997-01-31 -20.3593           NaN
# 36630  320193.0   16.250  1997      2 1997-02-28  -2.2556           NaN
# 36631  320193.0   18.250  1997      3 1997-03-31  12.3077           NaN
# 36632  320193.0   17.000  1997      4 1997-04-30  -6.8493           NaN
# 36633  320193.0   16.625  1997      5 1997-05-31  -2.2059           NaN
# ...         ...      ...   ...    ...        ...      ...           ...
# 36902  320193.0  248.760  2019     10 2019-10-31  11.0684  4.443265e+09
# 36903  320193.0  267.250  2019     11 2019-11-30   7.7424  4.443265e+09
# 36904  320193.0  293.650  2019     12 2019-12-31   9.8784  4.443265e+09
# 36905  320193.0  309.510  2020      1 2020-01-31   5.4010  4.375480e+09
# 36906  320193.0      NaN  2020      2 2020-02-29      NaN           NaN
#
#               mkcap   tic  nextmonth_return
# 36629           NaN  AAPL           -2.2556
# 36630           NaN  AAPL           12.3077
# 36631           NaN  AAPL           -6.8493
# 36632           NaN  AAPL           -2.2059
# 36633           NaN  AAPL          -14.2857
# ...             ...   ...               ...
# 36902  1.105307e+12  AAPL            7.7424
# 36903  1.187463e+12  AAPL            9.8784
# 36904  1.304765e+12  AAPL            5.4010
# 36905  1.354255e+12  AAPL               NaN
# 36906           NaN  AAPL               NaN
#
# [278 rows x 10 columns]

# %%
filtercap= returns['mkcap'].isna()| returns['cik'].isna()

# %%
returns= returns[-filtercap]

# %%
returns
# Out:
#               cik  prccm  year  month   datadate      trt1m      cshom  \
# 17       730052.0  0.008  2002      6 2002-06-30        NaN  2683000.0
# 18       730052.0  0.001  2002      7 2002-07-31   -87.5000  2683000.0
# 19       730052.0  0.040  2002      8 2002-08-31  3900.0000  2683000.0
# 20       730052.0  0.040  2002      9 2002-09-30     0.0000  2683000.0
# 21       730052.0  0.040  2002     10 2002-10-31     0.0000  2683000.0
# ...           ...    ...   ...    ...        ...        ...        ...
# 4615090  921114.0  3.700  2019      9 2019-09-30   -16.8932  9959000.0
# 4615091  921114.0  4.150  2019     10 2019-10-31    12.1622  9934000.0
# 4615092  921114.0  4.380  2019     11 2019-11-30     5.5422  9934000.0
# 4615093  921114.0  3.250  2019     12 2019-12-31   -25.7991  9934000.0
# 4615094  921114.0  3.980  2020      1 2020-01-31    22.4615  9923000.0
#
#               mkcap   tic  nextmonth_return
# 17          21464.0  ANTQ          -87.5000
# 18           2683.0  ANTQ         3900.0000
# 19         107320.0  ANTQ            0.0000
# 20         107320.0  ANTQ            0.0000
# 21         107320.0  ANTQ            0.0000
# ...             ...   ...               ...
# 4615090  36848300.0  ARMP           12.1622
# 4615091  41226100.0  ARMP            5.5422
# 4615092  43510920.0  ARMP          -25.7991
# 4615093  32285500.0  ARMP           22.4615
# 4615094  39493540.0  ARMP               NaN
#
# [3173885 rows x 10 columns]

# %% [markdown]
# # rating preparation

# %%
lista
# Out:
# ['splticrm', 'spsdrm', 'spsticrm', 'spcsrc']

# %%
rating = df[['cik','splticrm', 'spsdrm', 'spsticrm', 'spcsrc','datadate']]

# %%
rating['datadate']=(pd.to_datetime(rating['datadate'],format='%Y%m%d'))
rating['month']= rating['datadate'].dt.month
rating['year']= rating['datadate'].dt.year
# Out:
# C:\Users\Joseph\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Joseph\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Joseph\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Merged Dataset

# %%
merge_dataset = pd.merge(returns,rating, left_on=['cik','year','month'], right_on= ['cik','year','month'], how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-148bdf9557f8> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.ticker as mtick
# ----> 5 merge_dataset = pd.merge(returns,rating, left_on=['cik','year','month'], right_on= ['cik','year','month'], how='left')
#
# NameError: name 'returns' is not defined

# %%
merge_dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-200be9f9abe6> in <module>
# ----> 1 merge_dataset
#
# NameError: name 'merge_dataset' is not defined

# %%
merge_dataset[-merge_dataset['splticrm'].isna()]['cik'].nunique()
# Out:
# 3867

# %%
#impor to csv so no need to rerun everything
merge_dataset.to_csv('merge_dataset.csv')

# %% [markdown]
# ## read in merge_dataset from here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
merge_dataset = pd.read_csv('merge_dataset.csv')
# Out:
# C:\Users\Derrick\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# merge_dataset
merge_dataset['day'] = 1
merge_dataset['date'] = pd.to_datetime(merge_dataset[['year', 'month','day']])

# %%
merge_dataset['splticrm'] = merge_dataset['splticrm'].fillna('NO DATA')

# %%
listrating= (list(merge_dataset['splticrm'].unique()))
listrating.sort()
superior = listrating[3:7]
good = listrating[0:3]
adequate = listrating[13:16]
speculative = listrating[10:13]
highly_speculative = listrating[7:10]
highly_speculative.append(listrating[17])
highly_speculative.append(listrating[18])
default=[ 'CCC-','D','CC']
nodata=[ 'NO DATA']

#https://www.tdsecurities.com/tds/content/CMkt_RatingsCorrelation?language=en_CA

# %%
twodim=[]
twodim.append(superior)
twodim.append(good)
twodim.append(adequate)
twodim.append(speculative)
twodim.append(highly_speculative)
twodim.append(default)
twodim.append(nodata)
twodim
# Out:
# [['AA', 'AA+', 'AA-', 'AAA'],
#  ['A', 'A+', 'A-'],
#  ['BBB', 'BBB+', 'BBB-'],
#  ['BB', 'BB+', 'BB-'],
#  ['B', 'B+', 'B-', 'CCC', 'CCC+'],
#  ['CCC-', 'D', 'CC'],
#  ['NO DATA']]

# %%
def check_rating(rating):
    
    if rating in superior:
        return 'superior'
    elif rating in good:
        return 'good'
    elif rating in adequate:
        return 'adequate'
    elif rating in speculative:
        return 'speculative'
    elif rating in highly_speculative:
        return 'highly_speculative'
    elif rating in default:
        return 'default'
    elif rating in nodata:
        return 'nodata'
    
# merge_dataset['re-rating']= np.where((merge_dataset['splticrm'].isin(superior), ma)

# %%
merge_dataset['re_rating'] = merge_dataset['splticrm'].map(check_rating)

# %%
# grouped =

# %%
# #calculate value weight for top
# group = top.groupby('date')['tna'].sum().reset_index()
# top = pd.merge(top, group, how='left', left_on='date', right_on='date', suffixes=('', '_top'))
# top['value_weight'] = top['tna'] / top['tna_top']
# top['m1_value'] = (top['m+1_ret'].astype(float))* top['value_weight'].astype(float)

# %%
merge_dataset.groupby(['re_rating','date'])['mkcap'].sum().reset_index()
# Out:
#      re_rating       date         mkcap
# 0     adequate 1998-04-01  1.615745e+12
# 1     adequate 1998-05-01  1.561624e+12
# 2     adequate 1998-06-01  1.621900e+12
# 3     adequate 1998-07-01  1.636418e+12
# 4     adequate 1998-08-01  1.378277e+12
# ...        ...        ...           ...
# 1619  superior 2016-10-01  5.439565e+12
# 1620  superior 2016-11-01  5.462264e+12
# 1621  superior 2016-12-01  5.584636e+12
# 1622  superior 2017-01-01  5.634819e+12
# 1623  superior 2017-02-01  5.869351e+12
#
# [1624 rows x 3 columns]

# %%
total = merge_dataset.groupby(['re_rating','date'])['mkcap'].sum().reset_index()
merge_dataset = pd.merge(merge_dataset, total, how='left', left_on= ['date','re_rating'], right_on=['date','re_rating'] , suffixes=('', '_total'))

# %%
merge_dataset['weight'] = merge_dataset['mkcap'] / merge_dataset['mkcap_total']
merge_dataset['weight_return'] = merge_dataset['nextmonth_return'] * merge_dataset['weight']

# %%
# merge_dataset.groupby('date')['weight_return'].sum().to_csv('test.csv')

# %%
grouped =merge_dataset.groupby(['re_rating','year','month','date'])['weight_return'].agg(['sum','count']).reset_index()
# grouped = grouped.rename(columns = {'splticrm': 'rating'})

# %%
# grouped[grouped['rating'] == 'CCC']

# %%
# merge_dataset.groupby(['year','month','splticrm'])[['nextmonth_return']]#.count().to_csv('groupby_count.csv')
# merge_dataset.groupby(['year','month','splticrm'])[['nextmonth_return']]#.count().to_csv('groupby_mean.csv')

# %%
rate_list = list(grouped['re_rating'].unique())

# %%
grouped
# Out:
#      re_rating  year  month       date        sum  count
# 0     adequate  1998      4 1998-04-01  -2.703392    421
# 1     adequate  1998      5 1998-05-01   2.741193    413
# 2     adequate  1998      6 1998-06-01  -2.113302    416
# 3     adequate  1998      7 1998-07-01 -15.589924    413
# 4     adequate  1998      8 1998-08-01   9.002468    419
# ...        ...   ...    ...        ...        ...    ...
# 1619  superior  2016     10 2016-10-01   0.880749     28
# 1620  superior  2016     11 2016-11-01   2.411491     28
# 1621  superior  2016     12 2016-12-01   1.358772     28
# 1622  superior  2017      1 2017-01-01   4.707849     28
# 1623  superior  2017      2 2017-02-01   1.024637     28
#
# [1624 rows x 6 columns]

# %%
for i in rate_list:
#     plt.figure(figsize=(10,10))
    mask = grouped['re_rating'] == i
    ax = grouped[mask].plot(x = 'date', y = 'sum', title = i, color = 'teal', figsize = (15,5))
    plt.ylabel('average return')
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.show()

# %%
plt.figure(figsize=(10,5))
mask = grouped['rating'] == 'A'

ax = grouped[mask].plot(x = 'date', y = 'sum')
plt.ylabel('average return')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# df.plot(x="R", y=["F10.7", "Dst"], style='.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d4f12d2b8cfa> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 mask = grouped['rating'] == 'A'
#       3
#       4 ax = grouped[mask].plot(x = 'date', y = 'sum')
#       5 plt.ylabel('average return')
#
# ~\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'

# %%
grouped['re_rating'].value_counts()
# Out:
# nodata                262
# adequate              227
# good                  227
# superior              227
# speculative           227
# highly_speculative    227
# default               227
# Name: re_rating, dtype: int64

# %%
# for i in ['superior','good','adequate']:
mask = grouped['re_rating'] == 'superior'
df_superior = grouped[mask]
ax=df_superior.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'teal', figsize = (15,5), label = 'superior')

mask = grouped['re_rating'] == 'good'
df_good = grouped[mask]
df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'salmon', ax=ax, label = 'good') 


mask = grouped['re_rating'] == 'adequate'
df_good = grouped[mask]
df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'grey', ax=ax, label = 'adequate') 

mask = grouped['re_rating'] == 'speculative'
df_good = grouped[mask]
df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'pink', ax=ax, label = 'speculative', style = '--')


mask = grouped['re_rating'] == 'highly_speculative'
df_good = grouped[mask]
df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'tomato', ax=ax, label = 'highly_speculative', style = '-') 


mask = grouped['re_rating'] == 'default'
df_good = grouped[mask]
df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'darkgrey', ax=ax, label = 'default') 


# mask = grouped['re_rating'] == 'nodata'
# df_good = grouped[mask]
# df_good.plot(x = 'date', y = 'sum', title = 'Average Monthly Return by re_rating', color = 'red', ax=ax, label = 'nodata') 

# ax = grouped[mask].plot(x = 'date', y = 'sum', title = i, color = 'teal', figsize = (15,5))
# plt.ylabel('average return')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('average return')
# #     plt.show()
# ax = df1.plot()
# df2.plot(ax=ax)
plt.show()

# %%
year_1998_2017 = grouped.groupby('re_rating')[['sum']].mean()
year_1998_2017
print('average return difference between AAA and CCC from 1998 to 2017:', float(year_1998_2017.T['superior'] - year_1998_2017.T['default']),'percent')
year_1998_2017
# Out:
# average return difference between AAA and CCC from 1998 to 2017: 0.844714159209492 percent
#                          sum
# re_rating
# adequate            0.702591
# default            -0.354872
# good                0.672986
# highly_speculative  0.402603
# nodata              0.801030
# speculative         0.697632
# superior            0.489842

# %%
mask = grouped['year'] <= 2008
year_1998_2008 = grouped[mask].groupby('re_rating')[['sum']].mean()
print('average return difference between superior and default from 1998 to 2008:', float(year_1998_2008.T['superior'] - year_1998_2008.T['default']),'percent')
# Out:
# average return difference between superior and default from 1998 to 2008: 3.1057101206329936 percent

# %%
mask = grouped['year'] > 2008
grouped[mask].groupby('re_rating')[['sum']].mean()
year_2008_2017 = grouped[mask].groupby('re_rating')[['sum']].mean()
print('average return difference between superior and default from 2008 to 2017:', float(year_2008_2017.T['superior'] - year_2008_2017.T['default']),'percent')
# Out:
# average return difference between superior and default from 2008 to 2017: -2.1314948104194027 percent

# %%
grouped
# Out:
#      re_rating  year  month       date        sum  count
# 0     adequate  1998      4 1998-04-01  -2.703392    421
# 1     adequate  1998      5 1998-05-01   2.741193    413
# 2     adequate  1998      6 1998-06-01  -2.113302    416
# 3     adequate  1998      7 1998-07-01 -15.589924    413
# 4     adequate  1998      8 1998-08-01   9.002468    419
# ...        ...   ...    ...        ...        ...    ...
# 1619  superior  2016     10 2016-10-01   0.880749     28
# 1620  superior  2016     11 2016-11-01   2.411491     28
# 1621  superior  2016     12 2016-12-01   1.358772     28
# 1622  superior  2017      1 2017-01-01   4.707849     28
# 1623  superior  2017      2 2017-02-01   1.024637     28
#
# [1624 rows x 6 columns]

# %% [markdown]
# # Datareader

# %% [markdown]
# ### run the cell below if you are not able to  use datareader

# %%
#pip install yfinance

# %%
from pandas_datareader import data as pdr
import yfinance as yf
import datetime

start_sp = datetime.datetime(1998, 1 , 1)
end_sp = datetime.datetime(2020, 1, 31)


yf.pdr_override() # <== that's all it takes :-)
sp500 = pdr.get_data_yahoo('^GSPC', 
                           start_sp,
                             end_sp)
sp500= sp500.reset_index()

sp500['year']=sp500['Date'].dt.year
sp500['month']=sp500['Date'].dt.month

sp500=sp500.drop_duplicates(subset=['year','month'], keep="last")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sp500
# Out:
#            Date         Open         High          Low        Close  \
# 19   1998-01-30   985.489990   987.409973   979.630005   980.280029
# 38   1998-02-27  1048.670044  1051.660034  1044.400024  1049.339966
# 60   1998-03-31  1093.550049  1110.130005  1093.550049  1101.750000
# 81   1998-04-30  1094.630005  1116.969971  1094.630005  1111.750000
# 101  1998-05-29  1097.599976  1104.160034  1090.819946  1090.819946
# ...         ...          ...          ...          ...          ...
# 5470 2019-09-30  2967.070068  2983.850098  2967.070068  2976.739990
# 5493 2019-10-31  3046.899902  3046.899902  3023.189941  3037.560059
# 5513 2019-11-29  3147.179932  3150.300049  3139.340088  3140.979980
# 5534 2019-12-31  3215.179932  3231.719971  3212.030029  3230.780029
# 5555 2020-01-31  3282.330078  3282.330078  3214.679932  3225.520020
#
#         Adj Close      Volume  year  month
# 19     980.280029   613380000  1998      1
# 38    1049.339966   574480000  1998      2
# 60    1101.750000   674930000  1998      3
# 81    1111.750000   695600000  1998      4
# 101   1090.819946   556780000  1998      5
# ...           ...         ...   ...    ...
# 5470  2976.739990  3247610000  2019      9
# 5493  3037.560059  4139280000  2019     10
# 5513  3140.979980  1743020000  2019     11
# 5534  3230.780029  2893810000  2019     12
# 5555  3225.520020  4527830000  2020      1
#
# [265 rows x 9 columns]

# %%
sp500['next_month_close']= sp500['Adj Close'].shift(-1)
sp500['mkt_return']= (sp500['next_month_close']-sp500['Adj Close'])*100/sp500['Adj Close']

# %%
sp500
# Out:
#            Date         Open         High          Low        Close  \
# 19   1998-01-30   985.489990   987.409973   979.630005   980.280029
# 38   1998-02-27  1048.670044  1051.660034  1044.400024  1049.339966
# 60   1998-03-31  1093.550049  1110.130005  1093.550049  1101.750000
# 81   1998-04-30  1094.630005  1116.969971  1094.630005  1111.750000
# 101  1998-05-29  1097.599976  1104.160034  1090.819946  1090.819946
# ...         ...          ...          ...          ...          ...
# 5470 2019-09-30  2967.070068  2983.850098  2967.070068  2976.739990
# 5493 2019-10-31  3046.899902  3046.899902  3023.189941  3037.560059
# 5513 2019-11-29  3147.179932  3150.300049  3139.340088  3140.979980
# 5534 2019-12-31  3215.179932  3231.719971  3212.030029  3230.780029
# 5555 2020-01-31  3282.330078  3282.330078  3214.679932  3225.520020
#
#         Adj Close      Volume  year  month  next_month_close  mkt_return
# 19     980.280029   613380000  1998      1       1049.339966    7.044919
# 38    1049.339966   574480000  1998      2       1101.750000    4.994571
# 60    1101.750000   674930000  1998      3       1111.750000    0.907647
# 81    1111.750000   695600000  1998      4       1090.819946   -1.882622
# 101   1090.819946   556780000  1998      5       1133.839966    3.943824
# ...           ...         ...   ...    ...               ...         ...
# 5470  2976.739990  3247610000  2019      9       3037.560059    2.043177
# 5493  3037.560059  4139280000  2019     10       3140.979980    3.404704
# 5513  3140.979980  1743020000  2019     11       3230.780029    2.858982
# 5534  3230.780029  2893810000  2019     12       3225.520020   -0.162809
# 5555  3225.520020  4527830000  2020      1               NaN         NaN
#
# [265 rows x 11 columns]

# %%
regressiondata= pd.merge(grouped,sp500, left_on=['year','month'], right_on=['year','month'], how='left')

# %%
regressiondata
# Out:
#      re_rating  year  month       date        sum  count       Date  \
# 0     adequate  1998      4 1998-04-01  -2.703392    421 1998-04-30
# 1     adequate  1998      5 1998-05-01   2.741193    413 1998-05-29
# 2     adequate  1998      6 1998-06-01  -2.113302    416 1998-06-30
# 3     adequate  1998      7 1998-07-01 -15.589924    413 1998-07-31
# 4     adequate  1998      8 1998-08-01   9.002468    419 1998-08-31
# ...        ...   ...    ...        ...        ...    ...        ...
# 1619  superior  2016     10 2016-10-01   0.880749     28 2016-10-31
# 1620  superior  2016     11 2016-11-01   2.411491     28 2016-11-30
# 1621  superior  2016     12 2016-12-01   1.358772     28 2016-12-30
# 1622  superior  2017      1 2017-01-01   4.707849     28 2017-01-31
# 1623  superior  2017      2 2017-02-01   1.024637     28 2017-02-28
#
#              Open         High          Low        Close    Adj Close  \
# 0     1094.630005  1116.969971  1094.630005  1111.750000  1111.750000
# 1     1097.599976  1104.160034  1090.819946  1090.819946  1090.819946
# 2     1138.489990  1140.800049  1131.979980  1133.839966  1133.839966
# 3     1142.949951  1142.969971  1114.300049  1120.670044  1120.670044
# 4     1027.140015  1033.469971   957.280029   957.280029   957.280029
# ...           ...          ...          ...          ...          ...
# 1619  2129.780029  2133.250000  2125.530029  2126.149902  2126.149902
# 1620  2204.969971  2214.100098  2198.810059  2198.810059  2198.810059
# 1621  2251.610107  2253.580078  2233.620117  2238.830078  2238.830078
# 1622  2274.020020  2279.090088  2267.209961  2278.870117  2278.870117
# 1623  2366.080078  2367.790039  2358.959961  2363.639893  2363.639893
#
#           Volume  next_month_close  mkt_return
# 0      695600000       1090.819946   -1.882622
# 1      556780000       1133.839966    3.943824
# 2      757200000       1120.670044   -1.161533
# 3      645910000        957.280029  -14.579672
# 4      917500000       1017.010010    6.239552
# ...          ...               ...         ...
# 1619  3922400000       2198.810059    3.417452
# 1620  5533980000       2238.830078    1.820076
# 1621  2670900000       2278.870117    1.788436
# 1622  4087450000       2363.639893    3.719816
# 1623  4210140000       2362.719971   -0.038920
#
# [1624 rows x 15 columns]

# %% [markdown]
# # Regressing the sp500 and return of portfolio

# %%
# These are just code that i used to create series, it is not efficient in anyway 
masksuperior= regressiondata['re_rating']=='superior'
superior= regressiondata[masksuperior]
maskhighly_speculative= regressiondata['re_rating']=='highly_speculative'
highly_speculative= regressiondata[maskhighly_speculative]

#reset index but its annoying
highlyseries=highly_speculative['sum'].reset_index()
superiorseries=superior['sum'].reset_index()
spreturn=superior['mkt_return'].reset_index()

# %%
import statsmodels.api as sm
x=spreturn['mkt_return']
y=(superiorseries['sum']-highlyseries['sum'])
x = sm.add_constant(x)
# Out:
# C:\Users\Derrick\Anaconda2\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.OLS(y,x)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    sum   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     107.4
# Date:                Tue, 25 Feb 2020   Prob (F-statistic):           8.01e-21
# Time:                        16:30:42   Log-Likelihood:                -725.74
# No. Observations:                 227   AIC:                             1455.
# Df Residuals:                     225   BIC:                             1462.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4897      0.396      1.235      0.218      -0.292       1.271
# mkt_return    -0.9371      0.090    -10.362      0.000      -1.115      -0.759
# ==============================================================================
# Omnibus:                       14.076   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               37.037
# Skew:                          -0.090   Prob(JB):                     9.07e-09
# Kurtosis:                       4.971   Cond. No.                         4.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
